# %%
import pandas as pd
    
Brasilia_2003 = pd.read_csv('Dataset/Brasilia2003.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
Brasilia_2013 = pd.read_csv('Dataset/Brasilia2013.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
Brasilia_2023 = pd.read_csv('Dataset/Brasilia2023.CSV', encoding='iso-8859-1', decimal=',', delimiter=';', skiprows=8)
# Out:
# C:\Users\55739\AppData\Local\Temp\ipykernel_13684\1091994593.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
Brasilia_2003.head()
# Out:
#   DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0        2003-01-01      00:00                               0.0
# 1        2003-01-01      01:00                               0.0
# 2        2003-01-01      02:00                               0.0
# 3        2003-01-01      03:00                               0.0
# 4        2003-01-01      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              886.9
# 1                                              887.3
# 2                                              887.8
# 3                                              886.9
# 4                                              886.8
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            887.0
# 1                                            887.3
# 2                                            887.8
# 3                                            887.8
# 4                                            886.9
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/m²)  \
# 0                                             886.5                    -9999
# 1                                             886.9                    -9999
# 2                                             887.3                    -9999
# 3                                             886.9                    -9999
# 4                                             886.7                    -9999
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          20.3
# 1                                          19.9
# 2                                          19.8
# 3                                          19.5
# 4                                          19.2
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  18.8
# 1                                  18.5
# 2                                  18.5
# 3                                  18.5
# 4                                  18.0
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.4
# 1                                        20.3
# 2                                        20.1
# 3                                        19.8
# 4                                        19.5
#
#    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        20.2
# 1                                        19.9
# 2                                        19.8
# 3                                        19.5
# 4                                        19.2
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              18.9
# 1                                              18.8
# 2                                              18.8
# 3                                              18.6
# 4                                              18.5
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              18.7
# 1                                              18.5
# 2                                              18.4
# 3                                              18.4
# 4                                              18.0
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        91
# 1                                        92
# 2                                        92
# 3                                        94
# 4                                        94
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        90
# 1                                        91
# 2                                        92
# 3                                        92
# 4                                        93
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   91                                   308
# 1                                   92                                   302
# 2                                   92                                   302
# 3                                   94                                   295
# 4                                   93                                   313
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                         2.1                              1.4          NaN
# 1                         2.2                              1.3          NaN
# 2                         2.7                              1.6          NaN
# 3                         3.4                              2.0          NaN
# 4                         3.9                              2.5          NaN

# %%
Brasilia_2013.head()
# Out:
#   DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0        2013-01-01      00:00                               0.0
# 1        2013-01-01      01:00                               0.0
# 2        2013-01-01      02:00                               0.0
# 3        2013-01-01      03:00                               0.0
# 4        2013-01-01      04:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              885.7
# 1                                              886.5
# 2                                              886.9
# 3                                              886.5
# 4                                              886.0
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            885.7
# 1                                            886.5
# 2                                            886.9
# 3                                            886.9
# 4                                            886.5
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/m²)  \
# 0                                             885.1                  -9999.0
# 1                                             885.7                  -9999.0
# 2                                             886.5                  -9999.0
# 3                                             886.5                  -9999.0
# 4                                             886.0                  -9999.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          24.1
# 1                                          23.5
# 2                                          23.3
# 3                                          22.8
# 4                                          22.4
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  14.2
# 1                                  14.5
# 2                                  14.5
# 3                                  14.6
# 4                                  14.5
#
#    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        25.0
# 1                                        24.2
# 2                                        23.5
# 3                                        23.3
# 4                                        22.9
#
#    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        24.1
# 1                                        23.4
# 2                                        23.2
# 3                                        22.8
# 4                                        22.2
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              14.4
# 1                                              14.6
# 2                                              14.7
# 3                                              14.7
# 4                                              14.6
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                              13.9
# 1                                              14.2
# 2                                              14.4
# 3                                              14.4
# 4                                              14.3
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        54
# 1                                        58
# 2                                        59
# 3                                        60
# 4                                        62
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        50
# 1                                        54
# 2                                        56
# 3                                        57
# 4                                        59
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   54                                   112
# 1                                   57                                   110
# 2                                   58                                    91
# 3                                   60                                    81
# 4                                   61                                    86
#
#    VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                         4.6                              2.3          NaN
# 1                         5.0                              2.7          NaN
# 2                         5.4                              3.4          NaN
# 3                         5.4                              3.1          NaN
# 4                         5.3                              2.9          NaN

# %%
Brasilia_2023.head()
# Out:
#   DATA (YYYY-MM-DD)  Hora UTC  PRECIPITAï¿½ï¿½O TOTAL, HORï¿½RIO (mm)  \
# 0        2023-01-01  0000 UTC                                     0.0
# 1        2023-01-01  0100 UTC                                     0.0
# 2        2023-01-01  0200 UTC                                     0.0
# 3        2023-01-01  0300 UTC                                     0.0
# 4        2023-01-01  0400 UTC                                     0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887.7
# 1                                              888.1
# 2                                              887.8
# 3                                              887.8
# 4                                              887.6
#
#    PRESSï¿½O ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                              887.7
# 1                                              888.1
# 2                                              888.1
# 3                                              887.9
# 4                                              887.9
#
#    PRESSï¿½O ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                              887.2
# 1                                              887.7
# 2                                              887.8
# 3                                              887.7
# 4                                              887.6
#
#    RADIACAO GLOBAL (Kj-mï¿½)  TEMPERATURA DO AR - BULBO SECO, HORARIA (ï¿½C)  \
# 0                        NaN                                            20.1
# 1                        NaN                                            19.2
# 2                        NaN                                            19.3
# 3                        NaN                                            19.3
# 4                        NaN                                            19.7
#
#    TEMPERATURA DO PONTO DE ORVALHO (ï¿½C)  \
# 0                                    17.9
# 1                                    17.5
# 2                                    17.6
# 3                                    17.7
# 4                                    18.1
#
#    TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                            20.9
# 1                                            20.1
# 2                                            19.5
# 3                                            19.4
# 4                                            19.7
#
#    TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                            20.0
# 1                                            19.2
# 2                                            19.0
# 3                                            19.1
# 4                                            19.1
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                               19.2
# 1                                               17.8
# 2                                               17.8
# 3                                               17.8
# 4                                               18.1
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                               17.8
# 1                                               17.4
# 2                                               17.3
# 3                                               17.5
# 4                                               17.4
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      91.0
# 1                                      90.0
# 2                                      90.0
# 3                                      91.0
# 4                                      91.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      87.0
# 1                                      87.0
# 2                                      89.0
# 3                                      90.0
# 4                                      90.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                 87.0
# 1                                 90.0
# 2                                 90.0
# 3                                 91.0
# 4                                 90.0
#
#    VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))  VENTO, RAJADA MAXIMA (m-s)  \
# 0                                       187.0                         3.3
# 1                                       153.0                         2.9
# 2                                       145.0                         2.5
# 3                                       162.0                         3.2
# 4                                       140.0                         5.7
#
#    VENTO, VELOCIDADE HORARIA (m-s)  Unnamed: 19
# 0                              1.2          NaN
# 1                              0.8          NaN
# 2                              1.5          NaN
# 3                              1.4          NaN
# 4                              2.7          NaN

# %%
Brasilia_2023.rename(columns={'Data' : 'DATA (YYYY-MM-DD)'})
# Out:
#      DATA (YYYY-MM-DD)  Hora UTC  PRECIPITAï¿½ï¿½O TOTAL, HORï¿½RIO (mm)  \
# 0           2023-01-01  0000 UTC                                     0.0
# 1           2023-01-01  0100 UTC                                     0.0
# 2           2023-01-01  0200 UTC                                     0.0
# 3           2023-01-01  0300 UTC                                     0.0
# 4           2023-01-01  0400 UTC                                     0.0
# ...                ...       ...                                     ...
# 8755        2023-12-31  1900 UTC                                     0.0
# 8756        2023-12-31  2000 UTC                                     0.0
# 8757        2023-12-31  2100 UTC                                     0.0
# 8758        2023-12-31  2200 UTC                                     0.0
# 8759        2023-12-31  2300 UTC                                     0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 887.7
# 1                                                 888.1
# 2                                                 887.8
# 3                                                 887.8
# 4                                                 887.6
# ...                                                 ...
# 8755                                              884.2
# 8756                                              883.7
# 8757                                              883.5
# 8758                                              884.5
# 8759                                              885.3
#
#       PRESSï¿½O ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                                 887.7
# 1                                                 888.1
# 2                                                 888.1
# 3                                                 887.9
# 4                                                 887.9
# ...                                                 ...
# 8755                                              885.2
# 8756                                              884.3
# 8757                                              883.7
# 8758                                              884.5
# 8759                                              885.3
#
#       PRESSï¿½O ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                 887.2
# 1                                                 887.7
# 2                                                 887.8
# 3                                                 887.7
# 4                                                 887.6
# ...                                                 ...
# 8755                                              884.2
# 8756                                              883.7
# 8757                                              883.4
# 8758                                              883.5
# 8759                                              884.5
#
#       RADIACAO GLOBAL (Kj-mï¿½)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 8755                     1252.2
# 8756                     1178.8
# 8757                      873.0
# 8758                      104.0
# 8759                        NaN
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (ï¿½C)  \
# 0                                               20.1
# 1                                               19.2
# 2                                               19.3
# 3                                               19.3
# 4                                               19.7
# ...                                              ...
# 8755                                            26.1
# 8756                                            27.7
# 8757                                            25.5
# 8758                                            23.4
# 8759                                            22.6
#
#       TEMPERATURA DO PONTO DE ORVALHO (ï¿½C)  \
# 0                                       17.9
# 1                                       17.5
# 2                                       17.6
# 3                                       17.7
# 4                                       18.1
# ...                                      ...
# 8755                                    18.4
# 8756                                    18.1
# 8757                                    17.4
# 8758                                    18.2
# 8759                                    18.6
#
#       TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                               20.9
# 1                                               20.1
# 2                                               19.5
# 3                                               19.4
# 4                                               19.7
# ...                                              ...
# 8755                                            28.1
# 8756                                            27.7
# 8757                                            27.7
# 8758                                            25.5
# 8759                                            23.4
#
#       TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                               20.0
# 1                                               19.2
# 2                                               19.0
# 3                                               19.1
# 4                                               19.1
# ...                                              ...
# 8755                                            26.0
# 8756                                            25.8
# 8757                                            25.5
# 8758                                            23.4
# 8759                                            22.3
#
#       TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                                  19.2
# 1                                                  17.8
# 2                                                  17.8
# 3                                                  17.8
# 4                                                  18.1
# ...                                                 ...
# 8755                                               19.0
# 8756                                               18.2
# 8757                                               18.0
# 8758                                               18.2
# 8759                                               18.6
#
#       TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                                  17.8
# 1                                                  17.4
# 2                                                  17.3
# 3                                                  17.5
# 4                                                  17.4
# ...                                                 ...
# 8755                                               16.9
# 8756                                               16.9
# 8757                                               16.9
# 8758                                               17.4
# 8759                                               18.3
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                         91.0
# 1                                         90.0
# 2                                         90.0
# 3                                         91.0
# 4                                         91.0
# ...                                        ...
# 8755                                      64.0
# 8756                                      62.0
# 8757                                      62.0
# 8758                                      72.0
# 8759                                      79.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                         87.0
# 1                                         87.0
# 2                                         89.0
# 3                                         90.0
# 4                                         90.0
# ...                                        ...
# 8755                                      52.0
# 8756                                      53.0
# 8757                                      52.0
# 8758                                      61.0
# 8759                                      73.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                    87.0
# 1                                    90.0
# 2                                    90.0
# 3                                    91.0
# 4                                    90.0
# ...                                   ...
# 8755                                 63.0
# 8756                                 56.0
# 8757                                 61.0
# 8758                                 72.0
# 8759                                 78.0
#
#       VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))  VENTO, RAJADA MAXIMA (m-s)  \
# 0                                          187.0                         3.3
# 1                                          153.0                         2.9
# 2                                          145.0                         2.5
# 3                                          162.0                         3.2
# 4                                          140.0                         5.7
# ...                                          ...                         ...
# 8755                                         1.0                         5.3
# 8756                                       314.0                         5.2
# 8757                                       300.0                         5.1
# 8758                                       293.0                         4.8
# 8759                                       285.0                         3.7
#
#       VENTO, VELOCIDADE HORARIA (m-s)  Unnamed: 19
# 0                                 1.2          NaN
# 1                                 0.8          NaN
# 2                                 1.5          NaN
# 3                                 1.4          NaN
# 4                                 2.7          NaN
# ...                               ...          ...
# 8755                              2.1          NaN
# 8756                              1.9          NaN
# 8757                              2.7          NaN
# 8758                              2.0          NaN
# 8759                              1.4          NaN
#
# [8760 rows x 20 columns]

# %%
dataf = pd.concat([Brasilia_2003, Brasilia_2013, Brasilia_2023])
print(dataf)
# Out:
#      DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0           2003-01-01      00:00                               0.0
# 1           2003-01-01      01:00                               0.0
# 2           2003-01-01      02:00                               0.0
# 3           2003-01-01      03:00                               0.0
# 4           2003-01-01      04:00                               0.0
# ...                ...        ...                               ...
# 8755        2023-12-31        NaN                               NaN
# 8756        2023-12-31        NaN                               NaN
# 8757        2023-12-31        NaN                               NaN
# 8758        2023-12-31        NaN                               NaN
# 8759        2023-12-31        NaN                               NaN
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 886.9
# 1                                                 887.3
# 2                                                 887.8
# 3                                                 886.9
# 4                                                 886.8
# ...                                                 ...
# 8755                                              884.2
# 8756                                              883.7
# 8757                                              883.5
# 8758                                              884.5
# 8759                                              885.3
#
#       PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                               887.0
# 1                                               887.3
# 2                                               887.8
# 3                                               887.8
# 4                                               886.9
# ...                                               ...
# 8755                                              NaN
# 8756                                              NaN
# 8757                                              NaN
# 8758                                              NaN
# 8759                                              NaN
#
#       PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                886.5
# 1                                                886.9
# 2                                                887.3
# 3                                                886.9
# 4                                                886.7
# ...                                                ...
# 8755                                               NaN
# 8756                                               NaN
# 8757                                               NaN
# 8758                                               NaN
# 8759                                               NaN
#
#       RADIACAO GLOBAL (KJ/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                     -9999.0                                          20.3
# 1                     -9999.0                                          19.9
# 2                     -9999.0                                          19.8
# 3                     -9999.0                                          19.5
# 4                     -9999.0                                          19.2
# ...                       ...                                           ...
# 8755                      NaN                                           NaN
# 8756                      NaN                                           NaN
# 8757                      NaN                                           NaN
# 8758                      NaN                                           NaN
# 8759                      NaN                                           NaN
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     18.8
# 1                                     18.5
# 2                                     18.5
# 3                                     18.5
# 4                                     18.0
# ...                                    ...
# 8755                                   NaN
# 8756                                   NaN
# 8757                                   NaN
# 8758                                   NaN
# 8759                                   NaN
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                           20.4  ...
# 1                                           20.3  ...
# 2                                           20.1  ...
# 3                                           19.8  ...
# 4                                           19.5  ...
# ...                                          ...  ...
# 8755                                         NaN  ...
# 8756                                         NaN  ...
# 8757                                         NaN  ...
# 8758                                         NaN  ...
# 8759                                         NaN  ...
#
#       RADIACAO GLOBAL (Kj-mï¿½)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 8755                     1252.2
# 8756                     1178.8
# 8757                      873.0
# 8758                      104.0
# 8759                        NaN
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (ï¿½C)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8755                                            26.1
# 8756                                            27.7
# 8757                                            25.5
# 8758                                            23.4
# 8759                                            22.6
#
#       TEMPERATURA DO PONTO DE ORVALHO (ï¿½C)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 8755                                    18.4
# 8756                                    18.1
# 8757                                    17.4
# 8758                                    18.2
# 8759                                    18.6
#
#       TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8755                                            28.1
# 8756                                            27.7
# 8757                                            27.7
# 8758                                            25.5
# 8759                                            23.4
#
#       TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8755                                            26.0
# 8756                                            25.8
# 8757                                            25.5
# 8758                                            23.4
# 8759                                            22.3
#
#       TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8755                                               19.0
# 8756                                               18.2
# 8757                                               18.0
# 8758                                               18.2
# 8759                                               18.6
#
#       TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (ï¿½C)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8755                                               16.9
# 8756                                               16.9
# 8757                                               16.9
# 8758                                               17.4
# 8759                                               18.3
#
#       VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))  VENTO, RAJADA MAXIMA (m-s)  \
# 0                                            NaN                         NaN
# 1                                            NaN                         NaN
# 2                                            NaN                         NaN
# 3                                            NaN                         NaN
# 4                                            NaN                         NaN
# ...                                          ...                         ...
# 8755                                         1.0                         5.3
# 8756                                       314.0                         5.2
# 8757                                       300.0                         5.1
# 8758                                       293.0                         4.8
# 8759                                       285.0                         3.7
#
#       VENTO, VELOCIDADE HORARIA (m-s)
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 8755                              2.1
# 8756                              1.9
# 8757                              2.7
# 8758                              2.0
# 8759                              1.4
#
# [26280 rows x 34 columns]

# %%
dataf['DATA'] = pd.to_datetime(dataf['DATA (YYYY-MM-DD)'])
dataf.set_index('DATA', inplace=True)

# Verifique se o índice é do tipo DatetimeIndex
if not isinstance(dataf.index, pd.DatetimeIndex):
    raise TypeError("O índice não é do tipo DatetimeIndex. Verifique a conversão de data e a definição do índice.")

# Crie as colunas Ano, Mes e Dia
dataf['Ano'] = dataf.index.year
dataf['Mes'] = dataf.index.month
dataf['Dia'] = dataf.index.day

# Configure o índice para Ano, Mes e Dia
dataf.set_index(['Ano', 'Mes', 'Dia'], inplace=True)

# Exiba o DataFrame resultante
print(dataf)
# Out:
#              DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Ano  Mes Dia
# 2003 1   1          2003-01-01      00:00                               0.0
#          1          2003-01-01      01:00                               0.0
#          1          2003-01-01      02:00                               0.0
#          1          2003-01-01      03:00                               0.0
#          1          2003-01-01      04:00                               0.0
# ...                        ...        ...                               ...
# 2023 12  31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#
#               PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# Ano  Mes Dia
# 2003 1   1                                                886.9
#          1                                                887.3
#          1                                                887.8
#          1                                                886.9
#          1                                                886.8
# ...                                                         ...
# 2023 12  31                                               884.2
#          31                                               883.7
#          31                                               883.5
#          31                                               884.5
#          31                                               885.3
#
#               PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# Ano  Mes Dia
# 2003 1   1                                              887.0
#          1                                              887.3
#          1                                              887.8
#          1                                              887.8
#          1                                              886.9
# ...                                                       ...
# 2023 12  31                                               NaN
#          31                                               NaN
#          31                                               NaN
#          31                                               NaN
#          31                                               NaN
#
#               PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# Ano  Mes Dia
# 2003 1   1                                               886.5
#          1                                               886.9
#          1                                               887.3
#          1                                               886.9
#          1                                               886.7
# ...                                                        ...
# 2023 12  31                                                NaN
#          31                                                NaN
#          31                                                NaN
#          31                                                NaN
#          31                                                NaN
#
#               RADIACAO GLOBAL (KJ/m²)  \
# Ano  Mes Dia
# 2003 1   1                    -9999.0
#          1                    -9999.0
#          1                    -9999.0
#          1                    -9999.0
#          1                    -9999.0
# ...                               ...
# 2023 12  31                       NaN
#          31                       NaN
#          31                       NaN
#          31                       NaN
#          31                       NaN
#
#               TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# Ano  Mes Dia
# 2003 1   1                                            20.3
#          1                                            19.9
#          1                                            19.8
#          1                                            19.5
#          1                                            19.2
# ...                                                    ...
# 2023 12  31                                            NaN
#          31                                            NaN
#          31                                            NaN
#          31                                            NaN
#          31                                            NaN
#
#               TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# Ano  Mes Dia
# 2003 1   1                                    18.8
#          1                                    18.5
#          1                                    18.5
#          1                                    18.5
#          1                                    18.0
# ...                                            ...
# 2023 12  31                                    NaN
#          31                                    NaN
#          31                                    NaN
#          31                                    NaN
#          31                                    NaN
#
#               TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# Ano  Mes Dia                                              ...
# 2003 1   1                                          20.4  ...
#          1                                          20.3  ...
#          1                                          20.1  ...
#          1                                          19.8  ...
#          1                                          19.5  ...
# ...                                                  ...  ...
# 2023 12  31                                          NaN  ...
#          31                                          NaN  ...
#          31                                          NaN  ...
#          31                                          NaN  ...
#          31                                          NaN  ...
#
#               RADIACAO GLOBAL (Kj-mï¿½)  \
# Ano  Mes Dia
# 2003 1   1                          NaN
#          1                          NaN
#          1                          NaN
#          1                          NaN
#          1                          NaN
# ...                                 ...
# 2023 12  31                      1252.2
#          31                      1178.8
#          31                       873.0
#          31                       104.0
#          31                         NaN
#
#               TEMPERATURA DO AR - BULBO SECO, HORARIA (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
# ...                                                      ...
# 2023 12  31                                             26.1
#          31                                             27.7
#          31                                             25.5
#          31                                             23.4
#          31                                             22.6
#
#               TEMPERATURA DO PONTO DE ORVALHO (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                       NaN
#          1                                       NaN
#          1                                       NaN
#          1                                       NaN
#          1                                       NaN
# ...                                              ...
# 2023 12  31                                     18.4
#          31                                     18.1
#          31                                     17.4
#          31                                     18.2
#          31                                     18.6
#
#               TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
# ...                                                      ...
# 2023 12  31                                             28.1
#          31                                             27.7
#          31                                             27.7
#          31                                             25.5
#          31                                             23.4
#
#               TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
# ...                                                      ...
# 2023 12  31                                             26.0
#          31                                             25.8
#          31                                             25.5
#          31                                             23.4
#          31                                             22.3
#
#               TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
# ...                                                         ...
# 2023 12  31                                                19.0
#          31                                                18.2
#          31                                                18.0
#          31                                                18.2
#          31                                                18.6
#
#               TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
# ...                                                         ...
# 2023 12  31                                                16.9
#          31                                                16.9
#          31                                                16.9
#          31                                                17.4
#          31                                                18.3
#
#               VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))  \
# Ano  Mes Dia
# 2003 1   1                                           NaN
#          1                                           NaN
#          1                                           NaN
#          1                                           NaN
#          1                                           NaN
# ...                                                  ...
# 2023 12  31                                          1.0
#          31                                        314.0
#          31                                        300.0
#          31                                        293.0
#          31                                        285.0
#
#               VENTO, RAJADA MAXIMA (m-s)  VENTO, VELOCIDADE HORARIA (m-s)
# Ano  Mes Dia
# 2003 1   1                           NaN                              NaN
#          1                           NaN                              NaN
#          1                           NaN                              NaN
#          1                           NaN                              NaN
#          1                           NaN                              NaN
# ...                                  ...                              ...
# 2023 12  31                          5.3                              2.1
#          31                          5.2                              1.9
#          31                          5.1                              2.7
#          31                          4.8                              2.0
#          31                          3.7                              1.4
#
# [26280 rows x 34 columns]

# %%
precipitacao = dataf.groupby('Ano')['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].agg(['mean','min','max'])
pressao = dataf.groupby('Ano')['PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)'].agg(['mean','min','max'])
radiacao = dataf.groupby('Ano')['RADIACAO GLOBAL (KJ/m²)'].agg(['mean','min','max']).agg(['mean','min','max'])
temperatura = dataf.groupby('Ano')['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].agg(['mean','min','max'])
umidade = dataf.groupby('Ano')['UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)'].agg(['mean','min','max'])
velocidadedovento = dataf.groupby('Ano')['VENTO, VELOCIDADE HORARIA (m/s)'].agg(['mean','min','max'])

# %%
max_2003 = []
min_2003 = []
mean_2003 =[]

max_2013 = []
min_2013 = []
mean_2013 =[]

max_2023 = []
min_2023 = []
mean_2023 =[]

colunas = ['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)','TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)','TEMPERATURA DO PONTO DE ORVALHO (°C)','TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']
for coluna in colunas:
   #pegando todos os valores maximos minimos e médios dos anos citados.
  max_2003.append(dataf.xs(2003, level='Ano')[coluna].max()) 
  min_2003.append(dataf.xs(2003, level='Ano')[coluna].min())
  mean_2003.append(dataf.xs(2003, level='Ano')[coluna].mean())
  
  max_2013.append(dataf.xs(2013, level='Ano')[coluna].max()) 
  min_2013.append(dataf.xs(2013, level='Ano')[coluna].min())
  mean_2013.append(dataf.xs(2013, level='Ano')[coluna].mean())
  
  max_2023.append(dataf.xs(2023, level='Ano')[coluna].max()) 
  min_2023.append(dataf.xs(2023, level='Ano')[coluna].min())
  mean_2023.append(dataf.xs(2023, level='Ano')[coluna].mean())
  
  
  
  # comparando os dados , pegando valores de ano e mes.
max_2003_Mes = []
min_2003_Mes = []
mean_2003_Mes =[]

max_2013_Mes = []
min_2013_Mes = []
mean_2013_Mes =[]

max_2023_Mes = []
min_2023_Mes = []
mean_2023_Mes =[]

colunas = ['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)','TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)','TEMPERATURA DO PONTO DE ORVALHO (°C)','TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']
for coluna in colunas:
  
  max_2003_Mes.append(dataf.xs((2003,1),level=['Ano', 'Mes'])[coluna].max()) 
  min_2003_Mes.append(dataf.xs((2003,1),level=['Ano', 'Mes'])[coluna].min())
  mean_2003_Mes.append(dataf.xs((2003,1),level=['Ano', 'Mes'])[coluna].mean())

  max_2013_Mes.append(dataf.xs((2013,1),level=['Ano', 'Mes'])[coluna].max()) 
  min_2013_Mes.append(dataf.xs((2013,1),level=['Ano', 'Mes'])[coluna].min())
  mean_2013_Mes.append(dataf.xs((2013,1),level=['Ano', 'Mes'])[coluna].mean())

  max_2023_Mes.append(dataf.xs((2023,1),level=['Ano', 'Mes'])[coluna].max())
  min_2023_Mes.append(dataf.xs((2023,1),level=['Ano', 'Mes'])[coluna].min())
  mean_2023_Mes.append(dataf.xs((2023,1),level=['Ano', 'Mes'])[coluna].mean())


print(dataf)
# Out:
#              DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Ano  Mes Dia
# 2003 1   1          2003-01-01      00:00                               0.0
#          1          2003-01-01      01:00                               0.0
#          1          2003-01-01      02:00                               0.0
#          1          2003-01-01      03:00                               0.0
#          1          2003-01-01      04:00                               0.0
# ...                        ...        ...                               ...
# 2023 12  31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#          31         2023-12-31        NaN                               NaN
#
#               PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# Ano  Mes Dia
# 2003 1   1                                                886.9
#          1                                                887.3
#          1                                                887.8
#          1                                                886.9
#          1                                                886.8
# ...                                                         ...
# 2023 12  31                                               884.2
#          31                                               883.7
#          31                                               883.5
#          31                                               884.5
#          31                                               885.3
#
#               PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# Ano  Mes Dia
# 2003 1   1                                              887.0
#          1                                              887.3
#          1                                              887.8
#          1                                              887.8
#          1                                              886.9
# ...                                                       ...
# 2023 12  31                                               NaN
#          31                                               NaN
#          31                                               NaN
#          31                                               NaN
#          31                                               NaN
#
#               PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# Ano  Mes Dia
# 2003 1   1                                               886.5
#          1                                               886.9
#          1                                               887.3
#          1                                               886.9
#          1                                               886.7
# ...                                                        ...
# 2023 12  31                                                NaN
#          31                                                NaN
#          31                                                NaN
#          31                                                NaN
#          31                                                NaN
#
#               RADIACAO GLOBAL (KJ/m²)  \
# Ano  Mes Dia
# 2003 1   1                    -9999.0
#          1                    -9999.0
#          1                    -9999.0
#          1                    -9999.0
#          1                    -9999.0
# ...                               ...
# 2023 12  31                       NaN
#          31                       NaN
#          31                       NaN
#          31                       NaN
#          31                       NaN
#
#               TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# Ano  Mes Dia
# 2003 1   1                                            20.3
#          1                                            19.9
#          1                                            19.8
#          1                                            19.5
#          1                                            19.2
# ...                                                    ...
# 2023 12  31                                            NaN
#          31                                            NaN
#          31                                            NaN
#          31                                            NaN
#          31                                            NaN
#
#               TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# Ano  Mes Dia
# 2003 1   1                                    18.8
#          1                                    18.5
#          1                                    18.5
#          1                                    18.5
#          1                                    18.0
# ...                                            ...
# 2023 12  31                                    NaN
#          31                                    NaN
#          31                                    NaN
#          31                                    NaN
#          31                                    NaN
#
#               TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# Ano  Mes Dia                                              ...
# 2003 1   1                                          20.4  ...
#          1                                          20.3  ...
#          1                                          20.1  ...
#          1                                          19.8  ...
#          1                                          19.5  ...
# ...                                                  ...  ...
# 2023 12  31                                          NaN  ...
#          31                                          NaN  ...
#          31                                          NaN  ...
#          31                                          NaN  ...
#          31                                          NaN  ...
#
#               RADIACAO GLOBAL (Kj-mï¿½)  \
# Ano  Mes Dia
# 2003 1   1                          NaN
#          1                          NaN
#          1                          NaN
#          1                          NaN
#          1                          NaN
# ...                                 ...
# 2023 12  31                      1252.2
#          31                      1178.8
#          31                       873.0
#          31                       104.0
#          31                         NaN
#
#               TEMPERATURA DO AR - BULBO SECO, HORARIA (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
# ...                                                      ...
# 2023 12  31                                             26.1
#          31                                             27.7
#          31                                             25.5
#          31                                             23.4
#          31                                             22.6
#
#               TEMPERATURA DO PONTO DE ORVALHO (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                       NaN
#          1                                       NaN
#          1                                       NaN
#          1                                       NaN
#          1                                       NaN
# ...                                              ...
# 2023 12  31                                     18.4
#          31                                     18.1
#          31                                     17.4
#          31                                     18.2
#          31                                     18.6
#
#               TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
# ...                                                      ...
# 2023 12  31                                             28.1
#          31                                             27.7
#          31                                             27.7
#          31                                             25.5
#          31                                             23.4
#
#               TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
# ...                                                      ...
# 2023 12  31                                             26.0
#          31                                             25.8
#          31                                             25.5
#          31                                             23.4
#          31                                             22.3
#
#               TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
# ...                                                         ...
# 2023 12  31                                                19.0
#          31                                                18.2
#          31                                                18.0
#          31                                                18.2
#          31                                                18.6
#
#               TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (ï¿½C)  \
# Ano  Mes Dia
# 2003 1   1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
# ...                                                         ...
# 2023 12  31                                                16.9
#          31                                                16.9
#          31                                                16.9
#          31                                                17.4
#          31                                                18.3
#
#               VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))  \
# Ano  Mes Dia
# 2003 1   1                                           NaN
#          1                                           NaN
#          1                                           NaN
#          1                                           NaN
#          1                                           NaN
# ...                                                  ...
# 2023 12  31                                          1.0
#          31                                        314.0
#          31                                        300.0
#          31                                        293.0
#          31                                        285.0
#
#               VENTO, RAJADA MAXIMA (m-s)  VENTO, VELOCIDADE HORARIA (m-s)
# Ano  Mes Dia
# 2003 1   1                           NaN                              NaN
#          1                           NaN                              NaN
#          1                           NaN                              NaN
#          1                           NaN                              NaN
#          1                           NaN                              NaN
# ...                                  ...                              ...
# 2023 12  31                          5.3                              2.1
#          31                          5.2                              1.9
#          31                          5.1                              2.7
#          31                          4.8                              2.0
#          31                          3.7                              1.4
#
# [26280 rows x 34 columns]

# %%
# Certifique-se de que 'DATA (YYYY-MM-DD)' seja o nome correto da coluna
dataf['DATA (YYYY-MM-DD)'] = pd.to_datetime(dataf['DATA (YYYY-MM-DD)'], errors='coerce')

# Adicione uma coluna 'Estacao' com base nas estações do ano
dataf['Estacao'] = pd.cut(dataf['DATA (YYYY-MM-DD)'].dt.month,
bins=[0, 3, 6, 9, 12],
labels=['Verao', 'Outono', 'Inverno', 'Primavera'],
right=False)

# Agrupe por 'Ano' e 'Estacao' e calcule as médias
resultados = dataf.groupby(['Ano', 'Estacao']).agg({'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean'}).reset_index()

print(resultados)
# Out:
#      Ano    Estacao  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0   2003      Verao                                   -402.671469
# 1   2003     Outono                                  -1090.917437
# 2   2003    Inverno                                   -579.049864
# 3   2003  Primavera                                   -207.270330
# 4   2013      Verao                                     21.896398
# 5   2013     Outono                                    -60.512817
# 6   2013    Inverno                                     11.134918
# 7   2013  Primavera                                     22.000183
# 8   2023      Verao                                           NaN
# 9   2023     Outono                                           NaN
# 10  2023    Inverno                                           NaN
# 11  2023  Primavera                                           NaN
#
#     PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 0                        -423.453390
# 1                       -1109.401630
# 2                        -597.750453
# 3                        -228.799908
# 4                           0.430085
# 5                         -81.387047
# 6                          -9.054348
# 7                          -4.398168
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# C:\Users\55739\AppData\Local\Temp\ipykernel_13684\2959757502.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resultados = dataf.groupby(['Ano', 'Estacao']).agg({'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean'}).reset_index()

# %%
#exercicio3.3


# Criando uma nova coluna de datetime a partir da tupla (Ano, Mês, Dia)
dataf['Datetime'] = dataf.index.map(lambda x: pd.to_datetime(f"{x[0]}-{x[1]}-{x[2]}"))

# Criando uma nova coluna para representar o intervalo do dia
dataf['Intervalo'] = pd.cut(dataf['Datetime'].dt.hour, bins=[0, 6, 12, 18, 24], labels=['Madrugada', 'Manha', 'Tarde', 'Noite'], right=False)

# Filtrar dados para o dia 28 de setembro
dados_28_setembro = dataf[dataf['Datetime'].dt.day == 28]

# Calcular as médias para cada intervalo do dia
medias_por_intervalo = dados_28_setembro.groupby(['Intervalo']).agg({'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean'})

# Exibir as médias calculadas
print(medias_por_intervalo)
# Out:
#            TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# Intervalo
# Madrugada                                   -831.305382
# Manha                                               NaN
# Tarde                                               NaN
# Noite                                               NaN
#
#            PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# Intervalo
# Madrugada                         -850.4875
# Manha                                   NaN
# Tarde                                   NaN
# Noite                                   NaN
# C:\Users\55739\AppData\Local\Temp\ipykernel_13684\1548682643.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medias_por_intervalo = dados_28_setembro.groupby(['Intervalo']).agg({'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'mean', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'mean'})
